# %%
data = [10, 30, 20, 40, 70]
print (data[2])
data.append(50)
data.remove(10)
print(data)
data.sort()
print(data.index(30))
print(data)

data2 = (10, 20, 30)
print(data2)
print(data2[2])
# Out:
# 20
# [30, 20, 40, 70, 50]
# 1
# [20, 30, 40, 50, 70]
# (10, 20, 30)
# 30

# %%
Mahasiswa = {
    "Nama" : "Yogi Firnanda Saputra",
    "NIM" : "2511102441170"
}

print(Mahasiswa["Nama"])
print(Mahasiswa["NIM"])
print(Mahasiswa)


Mahasiswa["Nilai"] = 95
Mahasiswa["Kelas"] = "11-2A"
print(Mahasiswa)
# Out:
# Yogi Firnanda Saputra
# 2511102441170
# {'Nama': 'Yogi Firnanda Saputra', 'NIM': '2511102441170'}
# {'Nama': 'Yogi Firnanda Saputra', 'NIM': '2511102441170', 'Nilai': 95, 'Kelas': '11-2A'}

# %%
data2 = {10, 20, 30}
data2.add(40)
print(data2)

data3 = {15, 30, 50}

data_Union = data2.union(data3)
data_Union = data2 |data3
print(data_Union)

data_intersection = data2.intersection(data3)
data_intersection = data2 & data3
print(data_intersection)

data_difference = data2.difference(data3)
data_difference = data2 - data3
print(data_difference)
# Out:
# {40, 10, 20, 30}
# {50, 20, 40, 10, 30, 15}
# {30}
# {40, 10, 20}

# %%
nilai = int(input("Masukkan nilai: "))

hasil = nilai * 2

print("Hasil:", hasil)

# %%
a = int(input("Masukkan angka pertama: "))
b = int(input("Masukkan angka kedua"))

print("Penjumlahan:", a + b)
print("Penguarangan:", a - b)
print("Perkalian:", a * b)
print("Pembagian:", a / b)
print("Pembagian Bulat:", a // b)
print("Modulus:", a % b)
print("Pangkat:", a ** b )
