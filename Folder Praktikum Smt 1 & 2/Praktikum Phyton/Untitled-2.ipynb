# %%
# sequence
a = 10
b = 5
hasil = a + b 
print("Hasil:", hasil)

nilai = 60
if nilai >= 75:
    print("Lulus")
else:
    print("Tidak Lulus")
# Out:
# Hasil: 15
# Tidak Lulus

# %%
#iteration
for i in range(5):
    print("perulangan ke-", i)
    
i = 1

while i <= 5:
    print(i)
    i += 1
# Out:
# perulangan ke- 0
# perulangan ke- 1
# perulangan ke- 2
# perulangan ke- 3
# perulangan ke- 4
# 1
# 2
# 3
# 4
# 5
